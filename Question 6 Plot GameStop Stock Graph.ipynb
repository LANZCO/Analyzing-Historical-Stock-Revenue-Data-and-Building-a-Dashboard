# %%
import matplotlib.pyplot as plt

# 假设您有一个名为 gme_data 的 DataFrame，其中包含 GameStop 的股票数据
# gme_data = ...

# 使用 make_graph 函数绘制图形，并提供标题
plt.plot(gme_data['Close'], label='GameStop Stock Price')
plt.title('GameStop Stock Price History')
plt.legend()
plt.show()
